# %% [markdown]
# #                                      DISNEYLAND DREAMS - Analyzing Sentiments and Creating Personalized Chatbot Experiences

# %% [markdown]
# This project titled, “DISNEYLAND DREAMS – Analyzing Sentiments and creating Personalized Chatbot Experiences” aims in leveraging Natural Language Processing techniques to analyze customer sentiments expressed in textual data such as reviews and feedback with respect to Disneyland Park locations.
#
# This analysis aims to gain insights on visitor perceptions, emotions, and preferences regarding attractions and experiences at Disneyland locations in California, Paris, and Hong Kong. It can be accomplished by delving into the architecture of neural network model for understanding and predicting the user emotions from text messages.
#
# It is an important factor when it comes to monitoring Customer Satisfaction, Brand Reputation management, Predictive Analytics on future trends and personalized customer experience.

# %% [markdown]
# # Sentimental Analysis using Recurrent Neural Network variants:

# %% [markdown]
# **Importing basic libraries**:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Defining Disney dataset**:

# %%
balanced_disneydf = pd.read_csv(r'C:\Users\priya\Downloads\Projectwork\Balanced_Disneydf.csv')  
balanced_disneydf
# Out:
#       Rating                                        Review_Text  \
# 0          4  Had a better than expected time with my 2.5 ye...
# 1          5  Disney Land is the perfect home away from home...
# 2          5  Truly Disney.....  A place that showcases abou...
# 3          4  My wife and I visited Disneyland Park at the s...
# 4          3  As it says I've been here 3 times and this was...
# ...      ...                                                ...
# 7621       2  I will start off by saying that comments aroun...
# 7622       2  Disneyland is a great place to spend time with...
# 7623       2  This was my first trip to Disneyland and I was...
# 7624       2  The lines are low, thats good, the staff are r...
# 7625       2  I would not recommend going if you have been t...
#
#                      Branch  Sentiment  \
# 0     Disneyland_California          1
# 1     Disneyland_California          1
# 2       Disneyland_HongKong          1
# 3          Disneyland_Paris          1
# 4          Disneyland_Paris          1
# ...                     ...        ...
# 7621       Disneyland_Paris          0
# 7622       Disneyland_Paris          0
# 7623       Disneyland_Paris          0
# 7624       Disneyland_Paris          0
# 7625       Disneyland_Paris          0
#
#                                            Stemmed_Text  \
# 0     better expect time  year old girl  infant son ...
# 1     disney land perfect home away home  moment wal...
# 2     truli disney  place showcas disney charact  lo...
# 3     wife visit disneyland park start novemb  ever ...
# 4     say  time worst yet  level ride closur  peak s...
# ...                                                 ...
# 7621  start say comment around non disney thing most...
# 7622  disneyland great place spend time children rea...
# 7623  first trip disneyland pleasantli surpris much ...
# 7624  line low  that good  staff rude  guess that eu...
# 7625  would recommend go disney resort  one fall sho...
#
#                                         Lemmatized_Text
# 0     better expected time  year old girl  infant so...
# 1     disney land perfect home away home  moment wal...
# 2     truly disney  place showcase disney character ...
# 3     wife visited disneyland park start november  e...
# 4     say  time worst yet  level ride closure  peak ...
# ...                                                 ...
# 7621  start saying comment around non disney thing m...
# 7622  disneyland great place spend time child ready ...
# 7623  first trip disneyland pleasantly surprised muc...
# 7624  line low  thats good  staff rude  guess thats ...
# 7625  would recommend going disney resort  one fall ...
#
# [7626 rows x 6 columns]

# %%
balanced_disneydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7626 entries, 0 to 7625
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rating           7626 non-null   int64
#  1   Review_Text      7626 non-null   object
#  2   Branch           7626 non-null   object
#  3   Sentiment        7626 non-null   int64
#  4   Stemmed_Text     7626 non-null   object
#  5   Lemmatized_Text  7626 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 357.6+ KB

# %%
# To identify the number of rows and columns in a dataset
balanced_disneydf.shape
# Out:
# (7626, 6)

# %%
# Check for null values
balanced_disneydf.isnull().sum()
# Out:
# Rating             0
# Review_Text        0
# Branch             0
# Sentiment          0
# Stemmed_Text       0
# Lemmatized_Text    0
# dtype: int64

# %% [markdown]
# ## Sentimental Analysis using Recurrent Neural Network:

# %%
from keras.preprocessing.text import one_hot
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.callbacks import Callback
from sklearn.model_selection import train_test_split
from keras.layers import Dense,Embedding,LSTM,Dropout,BatchNormalization,Flatten
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from keras.initializers import glorot_normal
# Out:
# WARNING:tensorflow:From C:\Users\priya\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
rnn_disneydf = balanced_disneydf.copy()
rnn_disneydf.drop(columns=['Rating','Review_Text'],inplace=True,axis=1)
rnn_disneydf
# Out:
#                      Branch  Sentiment  \
# 0     Disneyland_California          1
# 1     Disneyland_California          1
# 2       Disneyland_HongKong          1
# 3          Disneyland_Paris          1
# 4          Disneyland_Paris          1
# ...                     ...        ...
# 7621       Disneyland_Paris          0
# 7622       Disneyland_Paris          0
# 7623       Disneyland_Paris          0
# 7624       Disneyland_Paris          0
# 7625       Disneyland_Paris          0
#
#                                            Stemmed_Text  \
# 0     better expect time  year old girl  infant son ...
# 1     disney land perfect home away home  moment wal...
# 2     truli disney  place showcas disney charact  lo...
# 3     wife visit disneyland park start novemb  ever ...
# 4     say  time worst yet  level ride closur  peak s...
# ...                                                 ...
# 7621  start say comment around non disney thing most...
# 7622  disneyland great place spend time children rea...
# 7623  first trip disneyland pleasantli surpris much ...
# 7624  line low  that good  staff rude  guess that eu...
# 7625  would recommend go disney resort  one fall sho...
#
#                                         Lemmatized_Text
# 0     better expected time  year old girl  infant so...
# 1     disney land perfect home away home  moment wal...
# 2     truly disney  place showcase disney character ...
# 3     wife visited disneyland park start november  e...
# 4     say  time worst yet  level ride closure  peak ...
# ...                                                 ...
# 7621  start saying comment around non disney thing m...
# 7622  disneyland great place spend time child ready ...
# 7623  first trip disneyland pleasantly surprised muc...
# 7624  line low  thats good  staff rude  guess thats ...
# 7625  would recommend going disney resort  one fall ...
#
# [7626 rows x 4 columns]

# %%
# Convert the columns of a dataframe into numpy arrays to perform One hot encoding
labels = rnn_disneydf['Sentiment'].values
texts  = rnn_disneydf['Stemmed_Text'].values
print(labels)
#labels1 = rnn_disneydf['Sentiment']
#print(labels1)
labels.shape
#np.array(labels)
# Out:
# [1 1 1 ... 0 0 0]
# (7626,)

# %%
# Create a Tokenizer object and fit it on the texts
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
print(tokenizer.word_index)
# Out:
# {'park': 1, 'ride': 2, 'disney': 3, 'time': 4, 'day': 5, 'disneyland': 6, 'nt': 7, 'go': 8, 'get': 9, 'one': 10, 'wait': 11, 'would': 12, 'visit': 13, 'line': 14, 'queue': 15, 'peopl': 16, 'place': 17, 'food': 18, 'hour': 19, 'kid': 20, 'even': 21, 'like': 22, 'year': 23, 'pass': 24, 'us': 25, 'see': 26, 'good': 27, 'went': 28, 'minut': 29, 'close': 30, 'staff': 31, 'realli': 32, 'show': 33, 'could': 34, 'great': 35, 'back': 36, 'long': 37, 'ticket': 38, 'mani': 39, 'much': 40, 'experi': 41, 'fast': 42, 'crowd': 43, 'attract': 44, 'magic': 45, 'around': 46, 'love': 47, 'children': 48, 'pari': 49, 'also': 50, 'charact': 51, 'take': 52, 'parad': 53, 'lot': 54, 'want': 55, 'enjoy': 56, 'first': 57, 'make': 58, 'got': 59, 'hotel': 60, 'famili': 61, 'walk': 62, 'disappoint': 63, 'money': 64, 'thing': 65, 'two': 66, 'well': 67, 'need': 68, 'world': 69, 'old': 70, 'price': 71, 'way': 72, 'use': 73, 'fun': 74, 'small': 75, 'expect': 76, 'open': 77, 'expens': 78, 'mountain': 79, 'stay': 80, 'say': 81, 'still': 82, 'better': 83, 'trip': 84, 'tri': 85, 'look': 86, 'everi': 87, 'never': 88, 'come': 89, 'littl': 90, 'think': 91, 'worth': 92, 'firework': 93, 'restaur': 94, 'seem': 95, 'big': 96, 'pm': 97, 'min': 98, 'everyth': 99, 'last': 100, 'california': 101, 'find': 102, 'best': 103, 'work': 104, 'florida': 105, 'area': 106, 'theme': 107, 'servic': 108, 'feel': 109, 'told': 110, 'know': 111, 'end': 112, 'pay': 113, 'help': 114, 'main': 115, 'space': 116, 'earli': 117, 'book': 118, 'night': 119, 'took': 120, 'sure': 121, 'adult': 122, 'alway': 123, 'shop': 124, 'anoth': 125, 'daughter': 126, 'made': 127, 'recommend': 128, 'mickey': 129, 'train': 130, 'spend': 131, 'member': 132, 'new': 133, 'start': 134, 'howev': 135, 'enough': 136, 'eat': 137, 'manag': 138, 'stand': 139, 'spent': 140, 'amaz': 141, 'half': 142, 'found': 143, 'least': 144, 'return': 145, 'whole': 146, 'though': 147, 'said': 148, 'euro': 149, 'queu': 150, 'land': 151, 'nice': 152, 'plan': 153, 'ask': 154, 'busi': 155, 'arriv': 156, 'buy': 157, 'let': 158, 'next': 159, 'must': 160, 'drink': 161, 'bad': 162, 'age': 163, 'save': 164, 'adventur': 165, 'rude': 166, 'ca': 167, 'holiday': 168, 'everyon': 169, 'bit': 170, 'differ': 171, 'left': 172, 'less': 173, 'meet': 174, 'studio': 175, 'abl': 176, 'cost': 177, 'clean': 178, 'quit': 179, 'ever': 180, 'someth': 181, 'noth': 182, 'sinc': 183, 'water': 184, 'young': 185, 'smoke': 186, 'fastpass': 187, 'front': 188, 'give': 189, 'thought': 190, 'allow': 191, 'miss': 192, 'meal': 193, 'definit': 194, 'full': 195, 'due': 196, 'princess': 197, 'actual': 198, 'run': 199, 'hong': 200, 'three': 201, 'photo': 202, 'wast': 203, 'friendli': 204, 'kong': 205, 'saw': 206, 'check': 207, 'away': 208, 'happi': 209, 'castl': 210, 'child': 211, 'leav': 212, 'cast': 213, 'street': 214, 'week': 215, 'etc': 216, 'part': 217, 'son': 218, 'pirat': 219, 'huge': 220, 'especi': 221, 'watch': 222, 'bring': 223, 'star': 224, 'travel': 225, 'offer': 226, 'wonder': 227, 'right': 228, 'poor': 229, 'felt': 230, 'entranc': 231, 'without': 232, 'problem': 233, 'car': 234, 'point': 235, 'guest': 236, 'compar': 237, 'came': 238, 'may': 239, 'french': 240, 'person': 241, 'room': 242, 'far': 243, 'hot': 244, 'break': 245, 'sever': 246, 'done': 247, 'custom': 248, 'total': 249, 'almost': 250, 'light': 251, 'second': 252, 'walt': 253, 'th': 254, 'stop': 255, 'orlando': 256, 'review': 257, 'anyth': 258, 'decid': 259, 'paid': 260, 'move': 261, 'thunder': 262, 'absolut': 263, 'coupl': 264, 'although': 265, 'smaller': 266, 'push': 267, 'includ': 268, 'turn': 269, 'keep': 270, 'lunch': 271, 'number': 272, 'excit': 273, 'put': 274, 'free': 275, 'everywher': 276, 'overal': 277, 'later': 278, 'reason': 279, 'special': 280, 'pictur': 281, 'either': 282, 'enter': 283, 'jone': 284, 'beauti': 285, 'pretti': 286, 'high': 287, 'probabl': 288, 'happen': 289, 'morn': 290, 'avail': 291, 'system': 292, 'sit': 293, 'short': 294, 'toilet': 295, 'lack': 296, 'christma': 297, 'ok': 298, 'ex ...

# %%
# Convert texts to sequences of integers
sequenced_txt = tokenizer.texts_to_sequences(texts)
#print(sequenced_txt)

total_words = len(tokenizer.word_index) + 1
print("Total Unique words: ",total_words)
print("Maximum length of text is ",max([len(x) for x in sequenced_txt]))
# Out:
# Total Unique words:  18528
# Maximum length of text is  1350

# %%
# Padding each encoded sentence to have a max_length
max_length= 1350
padded_txt = pad_sequences(sequenced_txt,max_length,padding="post")
print(padded_txt)
# Out:
# [[  83   76    4 ...    0    0    0]
#  [   3  151  595 ...    0    0    0]
#  [ 419    3   17 ...    0    0    0]
#  ...
#  [  57   84    6 ...    0    0    0]
#  [  14  698 1404 ...    0    0    0]
#  [  12  128    8 ...    0    0    0]]

# %%
from keras.utils import to_categorical

# Perform Label encoding
encoded_labels = to_categorical(labels)
print("Encoded Labels:",encoded_labels)
encoded_labels.shape
# Out:
# Encoded Labels: [[0. 1.]
#  [0. 1.]
#  [0. 1.]
#  ...
#  [1. 0.]
#  [1. 0.]
#  [1. 0.]]
# (7626, 2)

# %%
# Splitting the dataset into training and testing sets
#rnn_X_train,rnn_X_test,rnn_y_train,rnn_y_test = train_test_split(padded_txt,np.array(labels),test_size=0.2)
rnn_X_train,rnn_X_test,rnn_y_train,rnn_y_test = train_test_split(padded_txt,encoded_labels,test_size=0.2)
print(rnn_X_train.shape)
print(rnn_y_train.shape)
print(rnn_X_test.shape)
print(rnn_y_test.shape)
# Out:
# (6100, 1350)
# (6100, 2)
# (1526, 1350)
# (1526, 2)

# %% [markdown]
# ## Model Training and Evaluation:

# %% [markdown]
# ## Long Short Term Memory (LSTM) model  building and training:

# %%
# Define a RNN LSTM model

model = Sequential()
embedded_vector_size = 1350
model.add(Embedding(18528,embedded_vector_size,input_length=max_length,embeddings_initializer=glorot_normal()))
model.add(LSTM(128, return_sequences=True,dropout=0.6))
#model.add(LSTM(100, return_sequences=True,dropout=0.6))
#model.add(LSTM(100, return_sequences=True,dropout=0.6))
#model.add(LSTM(100, dropout=0.6))
#model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(2, activation='softmax'))

# %%
# Compiling the model
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=["accuracy"])
#model.compile(optimizer='adam', loss='binary_crossentropy',metrics=["accuracy"])
print(model.summary())
print("Model Creation Completed !")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 1350, 1350)        25012800
#
#  lstm_1 (LSTM)               (None, 1350, 128)         757248
#
#  dense_2 (Dense)             (None, 1350, 64)          8256
#
#  dense_3 (Dense)             (None, 1350, 2)           130
#
# =================================================================
# Total params: 25778434 (98.34 MB)
# Trainable params: 25778434 (98.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model Creation Completed !

# %% [markdown]
# ## Model Training and Evaluation:

# %%
history = model.fit(rnn_X_train,
                    rnn_y_train,
                    validation_data=(rnn_X_test,rnn_y_test),
                    #validation_split = 0.2,
                    epochs = 15,
                    batch_size = 64)
                    #callbacks = EarlyStopping(monitor ='val_loss',
                                              #patience = 3,
                                              #restore_best_weights = True))
# Out:
# Epoch 1/15
# 96/96 [==============================] - 823s 9s/step - loss: 0.2437 - accuracy: 0.9090 - val_loss: 0.3537 - val_accuracy: 0.8460
# Epoch 2/15
# 96/96 [==============================] - 819s 9s/step - loss: 0.1661 - accuracy: 0.9415 - val_loss: 0.4047 - val_accuracy: 0.8440
# Epoch 3/15
# 96/96 [==============================] - 826s 9s/step - loss: 0.0746 - accuracy: 0.9749 - val_loss: 0.5621 - val_accuracy: 0.8473
# Epoch 4/15
# 96/96 [==============================] - 839s 9s/step - loss: 0.0274 - accuracy: 0.9911 - val_loss: 0.8016 - val_accuracy: 0.8303
# Epoch 5/15
# 96/96 [==============================] - 850s 9s/step - loss: 0.0141 - accuracy: 0.9956 - val_loss: 0.9625 - val_accuracy: 0.8263
# Epoch 6/15
# 96/96 [==============================] - 854s 9s/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 1.1105 - val_accuracy: 0.8231
# Epoch 7/15
# 96/96 [==============================] - 855s 9s/step - loss: 0.0156 - accuracy: 0.9941 - val_loss: 0.9718 - val_accuracy: 0.8329
# Epoch 8/15
# 96/96 [==============================] - 862s 9s/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 1.0934 - val_accuracy: 0.8329
# Epoch 9/15
# 96/96 [==============================] - 859s 9s/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 1.2178 - val_accuracy: 0.8375
# Epoch 10/15
# 96/96 [==============================] - 862s 9s/step - loss: 5.8398e-04 - accuracy: 1.0000 - val_loss: 1.2813 - val_accuracy: 0.8368
# Epoch 11/15
# 96/96 [==============================] - 866s 9s/step - loss: 2.0511e-04 - accuracy: 1.0000 - val_loss: 1.3688 - val_accuracy: 0.8381
# Epoch 12/15
# 96/96 [==============================] - 866s 9s/step - loss: 9.6866e-05 - accuracy: 1.0000 - val_loss: 1.4218 - val_accuracy: 0.8381
# Epoch 13/15
# 96/96 [==============================] - 875s 9s/step - loss: 9.2577e-05 - accuracy: 1.0000 - val_loss: 1.4661 - val_accuracy: 0.8368
# Epoch 14/15
# 96/96 [==============================] - 874s 9s/step - loss: 5.2698e-05 - accuracy: 1.0000 - val_loss: 1.5022 - val_accuracy: 0.8375
# Epoch 15/15
# 96/96 [==============================] - 872s 9s/step - loss: 4.7079e-05 - accuracy: 1.0000 - val_loss: 1.5404 - val_accuracy: 0.8381

# %%
# Evaluate the model on test data
loss, accuracy = model.evaluate(rnn_X_test, rnn_y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 48/48 [==============================] - 44s 906ms/step - loss: 1.5404 - accuracy: 0.8381
# Test Loss: 1.5404380559921265
# Test Accuracy: 0.8381389379501343
